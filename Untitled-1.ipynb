# %%
# !pip install ydata_profiling
# Out:
# Requirement already satisfied: ydata_profiling in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (0.0.dev0)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (1.7.3)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (1.4.2)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (3.5.1)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (1.10.12)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (2.11.3)
# Requirement already satisfied: visions==0.7.5 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata_profiling) (0.7.5)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (1.22.4)
# Requirement already satisfied: htmlmin==0.1.12 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (0.12.3)
# Requirement already satisfied: requests<2.29,>=2.24.0 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (2.27.1)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (4.64.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (0.11.2)
# Requirement already satisfied: multimethod<1.10,>=1.4 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (1.9.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (0.13.2)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: pillow in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from imagehash==4.3.1->ydata_profiling) (9.0.1)
# Requirement already satisfied: PyWavelets in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from imagehash==4.3.1->ydata_profiling) (1.3.0)
# Requirement already satisfied: attrs>=19.3.0 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata_profiling) (21.4.0)
# Requirement already satisfied: networkx>=2.4 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata_profiling) (2.7.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->ydata_profiling) (0.2.0)
# WARNING: visions 0.7.5 does not provide the extra 'type-image-path'
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata_profiling) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata_profiling) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata_profiling) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from matplotlib<3.7,>=3.2->ydata_profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata_profiling) (2022.1)
# Requirement already satisfied: joblib>=0.14.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.4.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from pydantic<1.11,>=1.8.1->ydata_profiling) (4.11.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata_profiling) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata_profiling) (2024.2.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from requests<2.29,>=2.24.0->ydata_profiling) (3.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from statsmodels<0.14,>=0.13.2->ydata_profiling) (0.5.2)
# Requirement already satisfied: six in /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata_profiling) (1.16.0)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import umap.umap_ as umap
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px
from mpl_toolkits.mplot3d import Axes3D
from ydata_profiling import ProfileReport
# Out:
# /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages/numba/core/decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages/visions/backends/shared/nan_handling.py:51: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def hasna(x: np.ndarray) -> bool:

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.tree import plot_tree


pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
covid__file = 'data_municipalities.csv'

covid_df = pd.read_csv(covid__file)

covid_df.head(5)
# Out:
#    municipality_code municipality_name  county_code  percent_vaccinated  \
# 0             201011       Bolesławiec       201000                56.9
# 1             201022       Bolesławiec       201000                47.7
# 2             201032          Gromadka       201000                49.5
# 3             201043      Nowogrodziec       201000                47.5
# 4             201052        Osiecznica       201000                52.2
#
#    population_total  population_total_m  population_total_f  \
# 0             37659               17610               20049
# 1             14967                7473                7494
# 2              5156                2559                2597
# 3             14852                7414                7438
# 4              7358                3703                3655
#
#    population_0_4_total  population_0_4_total_m  population_0_4_total_f  \
# 0                  1585                     821                     764
# 1                   862                     471                     391
# 2                   237                     123                     114
# 3                   817                     432                     385
# 4                   397                     206                     191
#
#    population_5_9_total  population_5_9_total_m  population_5_9_total_f  \
# 0                  1662                     831                     831
# 1                   838                     426                     412
# 2                   256                     121                     135
# 3                   819                     429                     390
# 4                   389                     192                     197
#
#    population_10_14_total  population_10_14_total_m  population_10_14_total_f  \
# 0                    1751                       921                       830
# 1                     928                       468                       460
# 2                     271                       135                       136
# 3                     872                       454                       418
# 4                     468                       244                       224
#
#    population_15_19_total  population_15_19_total_m  population_15_19_total_f  \
# 0                    1498                       750                       748
# 1                     758                       382                       376
# 2                     230                       127                       103
# 3                     761                       405                       356
# 4                     414                       196                       218
#
#    population_20_24_total  population_20_24_total_m  population_20_24_total_f  \
# 0                    1544                       798                       746
# 1                     805                       422                       383
# 2                     296                       166                       130
# 3                     845                       443                       402
# 4                     403                       212                       191
#
#    population_25_29_total  population_25_29_total_m  population_25_29_total_f  \
# 0                    2027                       962                      1065
# 1                     934                       478                       456
# 2                     337                       181                       156
# 3                     947                       488                       459
# 4                     502                       260                       242
#
#    population_30_34_total  population_30_34_total_m  population_30_34_total_f  \
# 0                    2731                      1389                      1342
# 1                    1131                       589                       542
# 2                     373                       201                       172
# 3                    1154                       590                       564
# 4                     591                       314                       277
#
#    population_35_39_total  population_35_39_total_m  population_35_39_total_f  \
# 0                    3074                      1594                      1480
# 1                    1217                       614                       603
# 2                     395                       214                       181
# 3                    1277                       668                       609
# 4                     633                       347                       286
#
#    population_40_44_total  population_40_44_total_m  population_40_44_total_f  \
# 0                    3058                      1504                      1554
# 1                    1252                       648                       604
# 2                     403                       200                       203
# 3                    1213                       617                       596
# 4                     611                       312                       299
#
#    population_45_49_total  population_45_49_total_m  population_45_49_total_f  \
# 0                    2702                      1334                      1368
# 1                    1167                       598                       569
# 2                     391                       187                       204
# 3                    1003                       515                       488
# 4                     573                       301                       272
#
#    population_50_54_total  population_50_54_total_m  population_50_54_total_f  \
# 0                    2058                      1030                      1028
# 1                     970                       477                       493
# 2                     279                       145                       134
# 3                     883                       441                       442
# 4                     422                       218                       204
#
#    population_55_59_total  population_55_59_total_m  population_55_59_total_f  \
# 0                    2209                      1044                      1165
# 1                     985                       492                       493
# 2                     364                       187                       177
# 3                    1019                       511                       508
# 4                     436                       216                       220
#
#    population_60_64_total  population_60_64_total_m  population_60_64_total_f  \
# 0                    3051                      1334                      1717
# 1                    1019                       509                       510
# 2                     393                       197                       196
# 3                    1084                       546                       538
# 4                     470                       235                       235
#
#    population_65_69_total  population_65_69_total_m  population_65_69_total_f  \
# 0                    3059                      1309                      1750
# 1                     880                       423                       457
# 2                     360                       164                       196
# 3                     839                       398                       441
# 4                     426                       206                       220
#
#    population_70_74_total  population_70_74_total_m  population_70_74_total_f  \
# 0                    2412                       962                      1450
# 1                     561                       257                       304
# 2                     236                       108                       128
# 3                     522                       222                       300
# 4                     271                       126                       145
#
#    population_75_79_total  population_75_79_total_m  population_75_79_total_f  \
# 0                    1220                       425                       795
# 1                     262                       111                       151
# 2                     114                        43                        71
# 3                     309                       114                       195
# 4                     118                        51                        67
#
#    population_80_84_total  population_80_84_total_m  population_80_84_total_f  \
# 0                    1053                       335                       718
# 1                     228                        71                       157
# 2                     114                        36                        78
# 3                     252                        96                       156
# 4                     117                        37                        80
#
#    area_km2  population_density  urbanization_rate  healthcare_advices  \
# 0        24              1597.8              100.0            202393.0
# 1       289                51.9                0.0             13532.0
# 2       268                19.3                0.0             11221.0
# 3       176                84.2               28.1             47211.0
# 4       437                16.8                0.0             38508.0
#
#    population_per_pharmacy  installations_watersupply  installations_toilet  \
# 0                     2092                       98.5                  98.0
# 1                    14967                       97.8                  97.2
# 2                     5156                       96.1                  93.6
# 3                     3713                       96.8                  95.9
# 4                     7358                       96.0                  95.7
#
#    installations_bathroom  installations_central_heating  \
# 0                    97.5                           87.1
# 1                    95.3                           83.2
# 2                    91.8                           79.1
# 3                    94.4                           77.3
# 4                    93.9                           71.6
#
#    installations_network_gas  appartment_area_per_person  \
# 0                       90.6                        28.7
# 1                       28.8                        36.3
# 2                        0.2                        30.9
# 3                       14.2                        28.0
# 4                        4.1                        30.8
#
#   appartments_per_1000_persons  persons_per_appartment  persons_per_room  \
# 0                        444.9                    2.25              0.64
# 1                        305.9                    3.27              0.64
# 2                        345.8                    2.89              0.64
# 3                        305.5                    3.27              0.69
# 4                        397.0                    2.52              0.62
#
#    persons_per_library  library_books_per_1000_persons  \
# 0                18830                            2959
# 1                 2495                            4849
# 2                 5156                            2921
# 3                 2970                            2939
# 4                 1226                            6674
#
#    library_readers_per_1000_persons  library_loans_per_reader  forests_area  \
# 0                               143                      11.3         75.18
# 1                               119                      12.2        230.52
# 2                                37                      12.6        204.00
# 3                                48                       8.3        251.00
# 4                               167                       7.8         43.13
#
#   unemployed_total unemployed_f unemployed_m unemployed_up_to_25  \
# 0              761          409          352                  70
# 1              286          149          137                  52
# 2              119           73           46                  17
# 3              342          192          150                  57
# 4              175           93           82                  23
#
#   unemployed_over_50 unemployed_long_term  unemployment_rate  \
# 0                187                  275                3.6
# 1                 72                  105                3.1
# 2                 27                   47                3.8
# 3                 82                  135                3.7
# 4                 41                   74                3.8
#
#    unemployment_rate_m  unemployment_rate_f  bicycle_paths_per_100km2  \
# 0                  3.1                  4.1                    157.40
# 1                  2.8                  3.5                      3.95
# 2                  2.7                  5.2                      0.00
# 3                  3.0                  4.6                      0.00
# 4                  3.3                  4.5                      0.00
#
#    bicycle_paths_per_10k_persons  revenues_per_capita  \
# 0                           9.85              5312.66
# 1                           7.62              5396.32
# 2                           0.00              8219.43
# 3                           0.00              5067.58
# 4                           0.00              6377.16
#
#    revenues_per_capita_PIT  revenues_per_capita_CIT  expenditures_per_capita  \
# 0                  1067.74                    56.58                  4962.55
# 1                   926.60                    11.74                  4859.22
# 2                   690.41                   162.36                  6318.14
# 3                   644.43                    30.53                  4972.40
# 4                   786.19                    27.93                  4837.36
#
#    investment_expenditures_per_capita  children_3_5_in_kindergartens  \
# 0                              142.34                         1117.0
# 1                              895.71                          581.0
# 2                             1196.25                          662.0
# 3                              379.00                          615.0
# 4                              282.14                          762.0
#
#    net_scholarization  marriages_per_1000_persons  birthrate_per_1000_persons  \
# 0              113.11                         3.2                       -6.04
# 1               68.29                         3.2                       -0.60
# 2               89.37                         2.1                       -3.48
# 3               84.88                         4.1                       -0.67
# 4              100.15                         4.8                       -2.15
#
#    net_migrations_per_1000_persons  persons_running_business  \
# 0                             -5.3                      3099
# 1                             12.5                      1431
# 2                             -1.4                       257
# 3                              0.5                      1070
# 4                              1.7                       539
#
#    entities_registered_per_10k_persons
# 0                                 1323
# 1                                 1086
# 2                                  673
# 3                                  871
# 4                                  896

# %%
profile = ProfileReport(covid_df.sample(500),title="consumption Profile")

# %%
profile.to_widgets()
# Out:
# /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages/ydata_profiling/profile_report.py:505: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages/ydata_profiling/model/pandas/duplicates_pandas.py:37: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[duplicated_rows]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages/ydata_profiling/report/presentation/flavours/widget/correlation_table.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
# /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages/ydata_profiling/report/presentation/flavours/widget/duplicate.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
# /Users/mimuw2022/opt/anaconda3/lib/python3.9/site-packages/ydata_profiling/report/presentation/flavours/widget/sample.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
